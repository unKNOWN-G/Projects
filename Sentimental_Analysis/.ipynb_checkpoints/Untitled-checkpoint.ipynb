# %% [markdown]
# ## Header Files

# %%
import pandas as pd
import numpy as np
import random

import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer

from collections import Counter

from keras.preprocessing.sequence import pad_sequences
from keras.preprocessing.text import Tokenizer

from keras.models import Sequential
from keras.callbacks import ModelCheckpoint
from keras import layers, regularizers
from keras.layers import Embedding,LSTM,Dense,SpatialDropout1D,Dropout

lemmatizer = WordNetLemmatizer()
stop = stopwords.words('english')
stop.extend(['@', '.', '#', 'user'])

# %% [markdown]
# ## Loading Train and Test Data

# %%
train_data_add = "./Data/train.csv"
test_data_add = "./Data/test.csv"
train_data = pd.read_csv(train_data_add)
test_data = pd.read_csv(test_data_add)

# %% [markdown]
# ## Checking Data

# %%
print("Training Data")
print(train_data.head(3))
print("Length of Test data = ", len(train_data))
print("\nTest Data")
print(test_data.head(3))
print("Length of Test data = ", len(test_data))
# Out:
# Training Data
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# Length of Test data =  31962
#
# Test Data
#       id                                              tweet
# 0  31963  #studiolife #aislife #requires #passion #dedic...
# 1  31964   @user #white #supremacists want everyone to s...
# 2  31965  safe ways to heal your #acne!!    #altwaystohe...
# Length of Test data =  17197

# %% [raw]
#             Pre-processing of data
#     0) Making Every tweet to lowercase
#     1) Tokenization
#     2) Stop Word
#     3) Lemmatization

# %%
# Converting to Lower Case
for i in range(len(train_data)):
    train_data.iloc[i, 2] = train_data.iloc[i, 2].lower()
print(train_data.head(5))
# Out:
#    id  label                                              tweet
# 0   1      0   @user when a father is dysfunctional and is s...
# 1   2      0  @user @user thanks for #lyft credit i can't us...
# 2   3      0                                bihday your majesty
# 3   4      0  #model   i love u take with u all the time in ...
# 4   5      0             factsguide: society now    #motivation

# %% [markdown]
# ## Tokenization

# %%
tokens = []
for i in range(len(train_data)):
    tokens.append(nltk.word_tokenize(train_data.iloc[i, 2]))
print("After Tokenizing          : ", tokens[0])
# Out:
# After Tokenizing          :  ['@', 'user', 'when', 'a', 'father', 'is', 'dysfunctional', 'and', 'is', 'so', 'selfish', 'he', 'drags', 'his', 'kids', 'into', 'his', 'dysfunction', '.', '#', 'run']

# %% [markdown]
# ## Stop Word Removal

# %%
filtered_tokens = []
for i in range(len(tokens)):
    filtered_tokens.append([word for word in tokens[i] if word not in stop])
print("After Removing Stop Words : ", filtered_tokens[0])

tokenizer = Tokenizer(
    num_words = max_words,
    filters = '"#$%&()*+-/:;<=>@[\]^_`{|}~'
)
tokenizer.fit_on_texts(filtered_tokens)
# Out:
# After Removing Stop Words :  ['father', 'dysfunctional', 'selfish', 'drags', 'kids', 'dysfunction', 'run']
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-27-ac99861259a5> in <module>
#       5
#       6 tokenizer = Tokenizer(
# ----> 7     num_words = max_words,
#       8     filters = '"#$%&()*+-/:;<=>@[\]^_`{|}~'
#       9 )
#
# NameError: name 'max_words' is not defined

# %% [markdown]
# ## Lemmatization

# %%
lemmatizers = []
for i in range(len(filtered_tokens)):
    lemmatizers.append([lemmatizer.lemmatize(word) for word in filtered_tokens[i]])
print("After Lemmatization       : ", lemmatizers[0])
# Out:
# After Lemmatization       :  ['father', 'dysfunctional', 'selfish', 'drag', 'kid', 'dysfunction', 'run']

# %%
"""
 The next step currently is converting these words into numbers based on occurances and padding with zeros for length  
"""
a=0
for i in range(len(lemmatizers)):
    a=max(a,len(lemmatizers[i]))

# %%
print(a)
# Out:
# 114

# %% [markdown]
# ## Finding Highest frequency of words and creating the int dict

# %%
lemmatizers_to_int = Counter(total_words)
total_word_count = len(total_words)
sorted_order = lemmatizers_to_int.most_common(total_word_count)
print(lemmatizers_to_int)
vocab_to_index = {w: i+1 for i, (w, c) in enumerate(sorted_order)}
print(vocab_to_index)
# Out:
# Counter({'!': 14650, ',': 6305, "'s": 3219, ':': 3092, 'love': 2786, 'day': 2743, '?': 2600, ';': 2451, '...': 2314, '&': 2256, "n't": 2228, 'amp': 1776, 'u': 1670, 'happy': 1653, '-': 1370, 'time': 1235, 'life': 1212, 'â\x80¦': 1092, 'like': 1079, 'today': 1078, ')': 1047, "'m": 1020, 'get': 1000, 'new': 990, '``': 969, 'thankful': 946, 'positive': 932, 'father': 913, "''": 897, 'people': 878, 'good': 861, 'make': 843, 'bihday': 841, 'one': 836, '..': 824, 'smile': 808, '(': 789, 'see': 766, 'ca': 761, 'go': 750, 'friend': 733, 'want': 706, 'take': 672, 'work': 636, 'girl': 616, 'weekend': 615, '»': 608, 'healthy': 603, 'family': 600, 'need': 598, 'fun': 586, 'got': 581, 'week': 576, "'re": 565, 'summer': 561, 'way': 557, 'friday': 530, 'beautiful': 513, '2': 513, 'best': 512, 'great': 511, 'year': 510, 'bull': 506, 'going': 490, 'first': 480, 'thing': 479, 'really': 475, 'know': 465, 'wait': 465, 'morning': 460, 'music': 458, 'feel': 449, 'world': 448, 'back': 443, 'home': 443, 'tomorrow': 437, 'look': 437, 'think': 432, 'come': 432, 'dad': 429, 'affirmation': 424, 'sad': 419, 'cute': 418, 'orlando': 417, "'": 417, 'never': 416, 'fathersday': 408, 'night': 393, 'trump': 390, 'blog': 386, 'sunday': 383, 'right': 383, 'happiness': 383, 'model': 380, 'much': 372, 'say': 364, 'i_am': 352, '3': 349, 'well': 348, 'always': 346, 'even': 344, 'next': 343, 'finally': 341, 'last': 341, 'live': 338, "'ve": 335, '....': 330, 'ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 326, 'still': 326, 'urð\x9f\x93±': 325, 'ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 325, 'amazing': 325, 'gold': 316, 'show': 316, 'guy': 314, 'feeling': 313, 'let': 312, 'tonight': 311, 'â\x86\x9d': 309, 'find': 308, 'thank': 307, 'thanks': 306, 'silver': 305, 'woman': 305, 'ready': 304, 'selfie': 301, 'gt': 301, 'quote': 300, 'would': 299, 'altwaystoheal': 295, 'follow': 294, 'pay': 290, 'via': 288, 'little': 288, 'game': 288, 'man': 285, 'many': 285, 'everyone': 277, '4': 276, 'free': 275, 'black': 275, 'na': 275, 'baby': 273, 'dog': 273, 'looking': 270, 'hope': 268, 'old': 267, 'forex': 265, 'kid': 262, 'ever': 261, 'food': 261, 'getting': 257, 'another': 255, '*': 255, 'god': 254, "'ll": 251, 'blessed': 251, '1': 250, 'stop': 250, 'watch': 250, 'city': 250, 'peace': 249, 'hate': 248, 'place': 246, 'bear': 246, 'climb': 246, 'video': 243, 'enjoy': 241, 'sta': 241, 'white': 239, 'saturday': 239, 'keep': 239, 'sun': 236, 'help': 235, '2016': 234, 'news': 233, 'made': 231, 'whatever': 231, 'tweet': 231, 'every': 229, 'someone': 229, 'hour': 228, '%': 226, 'school': 224, 'might': 223, 'holiday': 220, 'child': 218, 'excited': 217, 'instagood': 217, 'polar': 216, 'boy': 215, 'thought': 215, 'change': 214, 'funny': 213, 'may': 211, '$': 209, 'wish': 209, 'lol': 208, 'coming': 207, 'wedding': 205, 'yes': 204, 'could': 203, 'nothing': 203, 'month': 200, 'nice': 199, 'angry': 199, 'beach': 199, 'healing': 198, 'believe': 197, 'big': 194, 'around': 194, '«': 194, 'better': 193, 'hea': 192, 'please': 192, 'found': 191, 'awesome': 191, 'long': 190, 'lot': 189, 'moment': 186, 'grateful': 186, 'team': 186, 'done': 185, 'word': 184, 'lt': 184, 'n': 184, 'give': 184, 'play': 184, 'attack': 182, 'america': 182, 'face': 181, 'end': 180, 'soon': 179, 'direct': 178, 'photo': 178, 'monday': 177, 'job': 177, 'proud': 177, 'cool': 177, 'dominate': 175, 'motivation': 174, 'book': 174, 'waiting': 174, 'bad': 174, 'true': 173, 'lost': 172, 'miss': 172, 'two': 172, 'something': 171, 'watching': 171, 'tear': 171, 'away': 170, 'travel': 169, 'dream': 169, 'without': 168, 'forward': 166, 'real': 165, 'fan': 162, 'shooting': 161, 'playing': 158, 'photooftheday': 158, 'oh': 157, 'fashion': 157, 'hot': 157, 'person': 156, 'â\x9d¤ï¸\x8f': 155, 'strong': 155, 'racing': 155, 'hair': 155, 'lovely': 154, 'yeah': 154, 'check': 154, 'followme': 153, 'ð\x9f\x98\x8a': 153, 'bing': 152, 'libtard': 151, 'left': 151, '|': 150, 'song': 150, 'bong': 150, 'cat': 147, 'rip': 146, 'gun': 146, 'wow': 146, 'hard': 145, 'se ...
# {'!': 1, ',': 2, "'s": 3, ':': 4, 'love': 5, 'day': 6, '?': 7, ';': 8, '...': 9, '&': 10, "n't": 11, 'amp': 12, 'u': 13, 'happy': 14, '-': 15, 'time': 16, 'life': 17, 'â\x80¦': 18, 'like': 19, 'today': 20, ')': 21, "'m": 22, 'get': 23, 'new': 24, '``': 25, 'thankful': 26, 'positive': 27, 'father': 28, "''": 29, 'people': 30, 'good': 31, 'make': 32, 'bihday': 33, 'one': 34, '..': 35, 'smile': 36, '(': 37, 'see': 38, 'ca': 39, 'go': 40, 'friend': 41, 'want': 42, 'take': 43, 'work': 44, 'girl': 45, 'weekend': 46, '»': 47, 'healthy': 48, 'family': 49, 'need': 50, 'fun': 51, 'got': 52, 'week': 53, "'re": 54, 'summer': 55, 'way': 56, 'friday': 57, 'beautiful': 58, '2': 59, 'best': 60, 'great': 61, 'year': 62, 'bull': 63, 'going': 64, 'first': 65, 'thing': 66, 'really': 67, 'know': 68, 'wait': 69, 'morning': 70, 'music': 71, 'feel': 72, 'world': 73, 'back': 74, 'home': 75, 'tomorrow': 76, 'look': 77, 'think': 78, 'come': 79, 'dad': 80, 'affirmation': 81, 'sad': 82, 'cute': 83, 'orlando': 84, "'": 85, 'never': 86, 'fathersday': 87, 'night': 88, 'trump': 89, 'blog': 90, 'sunday': 91, 'right': 92, 'happiness': 93, 'model': 94, 'much': 95, 'say': 96, 'i_am': 97, '3': 98, 'well': 99, 'always': 100, 'even': 101, 'next': 102, 'finally': 103, 'last': 104, 'live': 105, "'ve": 106, '....': 107, 'ð\x9f\x92¦ð\x9f\x92¦ð\x9f\x92¦': 108, 'still': 109, 'urð\x9f\x93±': 110, 'ð\x9f\x98\x99ð\x9f\x98\x8eð\x9f\x91\x84ð\x9f\x91': 111, 'amazing': 112, 'gold': 113, 'show': 114, 'guy': 115, 'feeling': 116, 'let': 117, 'tonight': 118, 'â\x86\x9d': 119, 'find': 120, 'thank': 121, 'thanks': 122, 'silver': 123, 'woman': 124, 'ready': 125, 'selfie': 126, 'gt': 127, 'quote': 128, 'would': 129, 'altwaystoheal': 130, 'follow': 131, 'pay': 132, 'via': 133, 'little': 134, 'game': 135, 'man': 136, 'many': 137, 'everyone': 138, '4': 139, 'free': 140, 'black': 141, 'na': 142, 'baby': 143, 'dog': 144, 'looking': 145, 'hope': 146, 'old': 147, 'forex': 148, 'kid': 149, 'ever': 150, 'food': 151, 'getting': 152, 'another': 153, '*': 154, 'god': 155, "'ll": 156, 'blessed': 157, '1': 158, 'stop': 159, 'watch': 160, 'city': 161, 'peace': 162, 'hate': 163, 'place': 164, 'bear': 165, 'climb': 166, 'video': 167, 'enjoy': 168, 'sta': 169, 'white': 170, 'saturday': 171, 'keep': 172, 'sun': 173, 'help': 174, '2016': 175, 'news': 176, 'made': 177, 'whatever': 178, 'tweet': 179, 'every': 180, 'someone': 181, 'hour': 182, '%': 183, 'school': 184, 'might': 185, 'holiday': 186, 'child': 187, 'excited': 188, 'instagood': 189, 'polar': 190, 'boy': 191, 'thought': 192, 'change': 193, 'funny': 194, 'may': 195, '$': 196, 'wish': 197, 'lol': 198, 'coming': 199, 'wedding': 200, 'yes': 201, 'could': 202, 'nothing': 203, 'month': 204, 'nice': 205, 'angry': 206, 'beach': 207, 'healing': 208, 'believe': 209, 'big': 210, 'around': 211, '«': 212, 'better': 213, 'hea': 214, 'please': 215, 'found': 216, 'awesome': 217, 'long': 218, 'lot': 219, 'moment': 220, 'grateful': 221, 'team': 222, 'done': 223, 'word': 224, 'lt': 225, 'n': 226, 'give': 227, 'play': 228, 'attack': 229, 'america': 230, 'face': 231, 'end': 232, 'soon': 233, 'direct': 234, 'photo': 235, 'monday': 236, 'job': 237, 'proud': 238, 'cool': 239, 'dominate': 240, 'motivation': 241, 'book': 242, 'waiting': 243, 'bad': 244, 'true': 245, 'lost': 246, 'miss': 247, 'two': 248, 'something': 249, 'watching': 250, 'tear': 251, 'away': 252, 'travel': 253, 'dream': 254, 'without': 255, 'forward': 256, 'real': 257, 'fan': 258, 'shooting': 259, 'playing': 260, 'photooftheday': 261, 'oh': 262, 'fashion': 263, 'hot': 264, 'person': 265, 'â\x9d¤ï¸\x8f': 266, 'strong': 267, 'racing': 268, 'hair': 269, 'lovely': 270, 'yeah': 271, 'check': 272, 'followme': 273, 'ð\x9f\x98\x8a': 274, 'bing': 275, 'libtard': 276, 'left': 277, '|': 278, 'song': 279, 'bong': 280, 'cat': 281, 'rip': 282, 'gun': 283, 'wow': 284, 'hard': 285, 'sex': 286, 'racist': 287, 'win': 288, 'twitter': 289, 'sleep': 290, 'buffalo': 291, 'flower': 292, 'everything': 293, '5': 294, 'gon': 295, 'j ...

# %% [markdown]
# ## Encoding to numbers

# %%
num_encoded_reviews = []
for i in range(len(lemmatizers)):
    num_encoded_reviews.append([vocab_to_index[word] for word in lemmatizers[i]])
print(num_encoded_reviews)
# Out:
# [[28, 15345, 2549, 3411, 149, 7456, 361], [122, 5279, 2281, 39, 11, 368, 551, 11, 1099, 7457, 4091, 7458, 15346, 9704], [33, 3159], [94, 5, 13, 43, 13, 16, 110, 1, 1, 1, 111, 108], [2716, 4, 1278, 241], [427, 9705, 437, 955, 258, 6165, 210, 631, 313, 3707, 132, 15347, 23, 15348], [2070, 76, 15349], [102, 184, 62, 62, 15350, 39, 11, 78, 904, 184, 1100, 163, 1279, 3708, 15351, 45], [1, 1, 1, 5, 1220, 1, 1, 1, 9706, 1077, 2411, 1363, 15352, 18], [647, 1, 22, 3, 3412, 1], [119, 1172, 2282, 1173, 1824, 37, 306, 21, 9707, 987, 5280, 183, 3709, 183, 195, 90, 123, 113, 148], [2549, 84, 9708, 2943, 717, 15353, 2549, 1419, 1364, 5], [23, 38, 440, 20, 1, 1, 15354, 15355], [1614, 307, 7459, 1500, 184, 9709, 1244, 85, 5281, 25, 1825], [441, 1, 1174, 9710, 1678, 7460, 6166, 7460], [3710, 9, 2944, 15356, 7461, 2944, 15357, 352], [26, 1679, 26, 27], [389, 820, 1], [57, 1, 603, 36, 211, 133, 1826, 4, 2412, 32, 30], [68, 2, 1737, 760, 177, 7462], [325, 30, 4092, 1827, 15358, 496, 1280, 5282, 873, 252, 140, 1101, 1365, 9711, 528], [82, 134, 1078, 35, 5283, 15359, 281, 2413, 194, 462], [836, 6, 4, 14, 136, 784, 1195, 3, 3, 46, 7, 16, 365, 10, 12, 8, 442, 1], [4604, 96, 2717, 4604], [486, 1038, 1281, 1501, 2071, 1138, 1], [58, 688, 2550, 2551, 196, 15360, 1, 1, 4093, 3160, 5], [36, 384, 1, 1, 9712, 15361, 9713, 2072, 1, 91, 1502, 5, 1, 15362], [61, 3711, 15363, 1102, 618, 9714], [14, 28, 3, 6, 15364], [566, 30, 492, 1317, 31, 88, 158, 136, 3, 852, 326, 30, 246, 49, 480, 282, 84], [86, 971, 587, 2414, 1282, 188, 4094, 77, 773], [6167, 16, 2179, 1283, 5284], [282, 1974, 3712, 1172, 258, 15365, 1175, 252, 118, 1, 35, 5285, 2, 480, 1103, 4095, 1039], [285, 236, 905, 2945, 937, 15366, 7463, 1888, 20, 1057, 15367], [3, 1680, 2946, 3713, 567, 50, 249, 19, 1615, 2283], [6168, 63, 4, 240, 63, 234, 178, 42, 718], [15368, 7464, 15369, 9715], [34, 224, 373, 4, 7465, 9716, 15370, 15371], [262, 2, 9717, 2552, 59, 182, 15372, 663, 2553, 349, 604], [26, 438, 26, 27], [103, 1104, 242, 106, 349, 4096, 9, 7466, 15373], [2718, 2, 9718, 258, 285, 2, 2284, 1005, 258, 5286, 1503, 211, 821], [17, 487, 4605, 2415, 6], [306, 395, 33, 33, 6169, 1, 38, 46, 3714], [270, 15374, 2719, 292, 1040, 2947, 15375, 1366, 2719, 15376], [112, 97, 27, 81], [94, 5, 13, 43, 13, 16, 110, 1, 1, 1, 111, 108], [2554, 308, 249, 40, 453, 278], [116, 418, 1975], [60, 315, 17, 1365, 1, 15377, 47, 18], [9719, 152, 125, 59, 2285, 15378, 2555, 9720, 474], [33, 52, 2416, 237, 15379, 33, 15380, 5, 2417], [15381, 9721, 65, 16], [117, 9722, 655, 406], [121, 1, 15382, 390, 5, 1, 266, 15383, 200, 15384, 2, 15385, 15386], [15387, 260, 15388, 1079, 1420, 1367, 1368], [117, 988, 5, 162], [14, 3413, 6, 2, 1681, 9723, 167, 28, 6, 9723, 73, 7467, 167], [2948, 16, 1284, 2180, 2948, 263, 7468, 568, 9724], [46, 35, 1, 1, 15389, 126, 1976, 1369, 874], [14, 44, 369, 4, 92, 85, 303, 431, 648, 572, 44, 303], [1196, 1370, 3, 104, 1318, 689, 9, 133, 15390, 719, 1504], [125, 341, 6170, 15391, 544, 6171], [106, 67, 541, 116, 4, 37], [690, 9725, 247, 1616, 114, 4606, 569, 15392, 10, 12, 8, 3, 293], [1738, 92, 107, 15393], [443, 180, 136, 1245, 3, 7469, 1139, 28, 3, 6], [22, 493, 14, 107, 15394, 182], [9726, 170, 6172, 39, 11, 7470, 7471, 511, 211, 468, 3161, 3162], [31, 70, 1, 1105, 655, 1, 9727, 47, 7472, 253, 271, 9728, 9729], [1682, 3715, 19, 2286, 1371, 2720], [24, 4097, 570, 1, 837, 1, 1, 7473, 2949], [95, 720, 691, 605, 1, 65, 84, 259, 3414, 248, 62, 147, 9730], [7474, 15395, 2950, 3163, 5287, 1421, 1617, 481, 9731, 2, 7474, 2, 15396, 9, 309], [9732, 65, 838, 1, 238], [1739, 4098, 802, 85, 2556, 2, 481, 906, 2557, 2, 1618], [7475, 9733, 2721], [407, 2, 170, 30, 4, 307, 30, 15397, 85, 409, 4607, 9734], [185, 4608, 20, 15398, 631, 481, 569, 1041, 7], [545, 2558, 5288, 2558, 1197, 15399, 267, 15400], [3716, 9735, 9736], [6173, 7476, 1176, 1022, 15401, 15402, 6174, 15403, 7477, 907], [1977, 3717, 10, 12, 8, 6175, 5289, 346, 4609], [3718, 283, 129, 11, 4610, 39, 11, 43, 283, 632, 366, 11, 159, 141, 1246, 1, 1177, 23, 1285, ...

# %% [markdown]
# ## Padding and truncating

# %%
padded_reviews = pad_sequences(num_encoded_reviews, maxlen=90)
print(padded_reviews)
y_train = np.asarray(np.array(train_data.iloc[:,1])).astype('float32').reshape((-1,1))
# Out:
# [[    0     0     0 ...   149  7456   361]
#  [    0     0     0 ...  7458 15346  9704]
#  [    0     0     0 ...     0    33  3159]
#  ...
#  [    0     0     0 ...  7208    44    82]
#  [    0     0     0 ...  1490  1491   491]
#  [    0     0     0 ...     0   121   131]]

# %%
ping=[]
for i in range(len(num_encoded_reviews)):
    ping.append((num_encoded_reviews[i],y_train[i]))
random.shuffle(ping)

training_set = ping[:20000]
testing_set = ping[20000:]

# %%
# Now we are ready to train our model through LSTM network
model = Sequential()
model.add(layers.Embedding(len(total_words),100))
model.add(layers.LSTM(30))
model.add(layers.Dense(1,activation='softmax', input_shape=(50,)))

model.compile(optimizer='adam',loss='binary_crossentropy', metrics=['accuracy'])

checkpoint1 = ModelCheckpoint("best_mode1_11-02-2021.hdf5",monitor='val-accuracy',save_best_only = True, save_weights_only= False)

# Our vectorized labels
model.fit(np.array(padded_reviews), y_train, validation_split=0.2 , epochs=50, callbacks=[checkpoint1], verbose=1 )
# Out:
# Epoch 1/50
#  15/800 [..............................] - ETA: 4:43 - loss: 0.6684 - accuracy: 0.0735
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-24-b95ec85acaac> in <module>
#      10
#      11 # Our vectorized labels
# ---> 12 model.fit(np.array(padded_reviews), y_train, validation_split=0.2 , epochs=50, callbacks=[checkpoint1], verbose=1 )
#
# ~\anaconda3\envs\Sentimental_Analysis\lib\site-packages\tensorflow\python\keras\engine\training.py in fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq, max_queue_size, workers, use_multiprocessing)
#    1098                 _r=1):
#    1099               callbacks.on_train_batch_begin(step)
# -> 1100               tmp_logs = self.train_function(iterator)
#    1101               if data_handler.should_sync:
#    1102                 context.async_wait()
#
# ~\anaconda3\envs\Sentimental_Analysis\lib\site-packages\tensorflow\python\eager\def_function.py in __call__(self, *args, **kwds)
#     826     tracing_count = self.experimental_get_tracing_count()
#     827     with trace.Trace(self._name) as tm:
# --> 828       result = self._call(*args, **kwds)
#     829       compiler = "xla" if self._experimental_compile else "nonXla"
#     830       new_tracing_count = self.experimental_get_tracing_count()
#
# ~\anaconda3\envs\Sentimental_Analysis\lib\site-packages\tensorflow\python\eager\def_function.py in _call(self, *args, **kwds)
#     853       # In this case we have created variables on the first call, so we run the
#     854       # defunned version which is guaranteed to never create variables.
# --> 855       return self._stateless_fn(*args, **kwds)  # pylint: disable=not-callable
#     856     elif self._stateful_fn is not None:
#     857       # Release the lock early so that multiple threads can perform the call
#
# ~\anaconda3\envs\Sentimental_Analysis\lib\site-packages\tensorflow\python\eager\function.py in __call__(self, *args, **kwargs)
#    2940       (graph_function,
#    2941        filtered_flat_args) = self._maybe_define_function(args, kwargs)
# -> 2942     return graph_function._call_flat(
#    2943         filtered_flat_args, captured_inputs=graph_function.captured_inputs)  # pylint: disable=protected-access
#    2944
#
# ~\anaconda3\envs\Sentimental_Analysis\lib\site-packages\tensorflow\python\eager\function.py in _call_flat(self, args, captured_inputs, cancellation_manager)
#    1916         and executing_eagerly):
#    1917       # No tape is watching; skip to running the function.
# -> 1918       return self._build_call_outputs(self._inference_function.call(
#    1919           ctx, args, cancellation_manager=cancellation_manager))
#    1920     forward_backward = self._select_forward_and_backward_functions(
#
# ~\anaconda3\envs\Sentimental_Analysis\lib\site-packages\tensorflow\python\eager\function.py in call(self, ctx, args, cancellation_manager)
#     553       with _InterpolateFunctionError(self):
#     554         if cancellation_manager is None:
# --> 555           outputs = execute.execute(
#     556               str(self.signature.name),
#     557               num_outputs=self._num_outputs,
#
# ~\anaconda3\envs\Sentimental_Analysis\lib\site-packages\tensorflow\python\eager\execute.py in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      57   try:
#      58     ctx.ensure_initialized()
# ---> 59     tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      60                                         inputs, attrs, num_outputs)
#      61   except core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
count=0
for i in range(len(train_data.iloc[:,1])):
    if(train_data.iloc[i,1]==1):
        count=count+1

# %%
count,len(train_data.iloc[:,1])-count

# %%
len(train_data.iloc[:,1])

# %%
model_lstm = Sequential()
model_lstm.add(Embedding(input_dim = len(vocab_to_index)+1, output_dim = 256, input_length = 70))
model_lstm.add(SpatialDropout1D(0.3))
model_lstm.add(LSTM(256, dropout = 0.3, recurrent_dropout = 0.3))
model_lstm.add(Dense(256, activation = 'relu'))
model_lstm.add(Dropout(0.3))
model_lstm.add(Dense(1, activation = 'softmax'))
model_lstm.compile(
    loss='binary_crossentropy',
    optimizer='Adam',
    metrics=['accuracy']
)

# %%
batch_size = 512
epochs = 8
X_train= np.array(padded_reviews)
y_train = np.array(train_data.iloc[:,1])

# %%
history = model_lstm.fit(
    X_train,
    y_train,
    validation_split = 0.1,
    epochs = 8,
    batch_size = 512
)

# %%
X_train[0]
